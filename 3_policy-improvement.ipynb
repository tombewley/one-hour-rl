# %% [markdown]
# # 3 | Policy Improvement: The Q-learning Algorithm
#
# Having evaluated our policy $\pi$, how can we go about obtaining a better one? This question is the heart of *policy improvement*, perhaps the fundamental concept of RL. Recall, when we performed policy evaluation we obtained the value of taking every action in every state. Thus, we can perform policy improvement readily by picking our current best estimate of the optimal action from each state -- so-called *greedy* action selection. Once we've obtained a new policy, we can evaluate it as before. Continually iterating between policy evaluation and policy improvement in this way, we are guarenteed to reach the optimal policy $\pi^*$ according to the policy improvement theorem.

# %%
from mdp import StudentMDP
mdp = StudentMDP(verbose=True)

# %%
from agent import QLearningAgent
agent = QLearningAgent(mdp, epsilon=1.0, alpha=0.2, gamma=0.9)

# %%
NUM_EPS = 50
mdp.ep = 0
while mdp.ep < NUM_EPS:
    state = mdp.reset()
    done = False
    while not done:
        action = agent.act(state)
        next_state, reward, done, info = mdp.step(action)
        agent.learn(state, action, reward, next_state, done)
        state = next_state

    print("Value function:")
    print(agent.Q)
    print("Policy:")
    print(agent.policy)
    print("Epsilon:", agent.epsilon)
    
    agent.epsilon = max(agent.epsilon - 1 / (NUM_EPS-1), 0)
# Out:
# =========================== EPISODE   1 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 2     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 3     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 4     | Class 3  | Study          | 10.0   | Pass       | False |
# | 5     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -0.4, 'Go on Facebook': -0.2}, 'Class 2': {'Study': -0.4, 'Fall asleep': 0.0}, 'Class 3': {'Study': 2.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': -0.4}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.5, 'Go on Facebook': 0.5}, 'Class 2': {'Study': 0.5, 'Fall asleep': 0.5}, 'Class 3': {'Study': 0.5, 'Go to the pub': 0.5}, 'Facebook': {'Keep scrolling': 0.5, 'Close Facebook': 0.5}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 1.0
# =========================== EPISODE   2 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 2     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 3     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 4     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 5     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 6     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 7     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 8     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -0.7200000000000001, 'Go on Facebook': -0.5938544000000001}, 'Class 2': {'Study': -0.4, 'Fall asleep': 0.0}, 'Class 3': {'Study': 2.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': -0.58808, 'Close Facebook': -1.09984}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.4897959183673469, 'Go on Facebook': 0.5102040816326531}, 'Class 2': {'Study': 0.4897959183673469, 'Fall asleep': 0.5102040816326531}, 'Class 3': {'Study': 0.5102040816326531, 'Go to the pub': 0.4897959183673469}, 'Facebook': {'Keep scrolling': 0.5102040816326531, 'Close Facebook': 0.4897959183673469}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.9795918367346939
# =========================== EPISODE   3 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -0.976, 'Go on Facebook': -0.5938544000000001}, 'Class 2': {'Study': -0.4, 'Fall asleep': 0.0}, 'Class 3': {'Study': 2.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': -0.58808, 'Close Facebook': -1.09984}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.47959183673469385, 'Go on Facebook': 0.5204081632653061}, 'Class 2': {'Study': 0.47959183673469385, 'Fall asleep': 0.5204081632653061}, 'Class 3': {'Study': 0.5204081632653061, 'Go to the pub': 0.47959183673469385}, 'Facebook': {'Keep scrolling': 0.5204081632653061, 'Close Facebook': 0.47959183673469385}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.9591836734693877
# =========================== EPISODE   4 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 2     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 3     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 4     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.1808, 'Go on Facebook': -0.7809379200000002}, 'Class 2': {'Study': -0.4, 'Fall asleep': 0.0}, 'Class 3': {'Study': 2.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': -0.7763184000000001, 'Close Facebook': -1.4204408256}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.4693877551020408, 'Go on Facebook': 0.5306122448979592}, 'Class 2': {'Study': 0.4693877551020408, 'Fall asleep': 0.5306122448979592}, 'Class 3': {'Study': 0.5306122448979592, 'Go to the pub': 0.4693877551020408}, 'Facebook': {'Keep scrolling': 0.5306122448979592, 'Close Facebook': 0.4693877551020408}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.9387755102040816
# =========================== EPISODE   5 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 2     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 3     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 4     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 5     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 6     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 7     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.34464, 'Go on Facebook': -1.1113274304000003}, 'Class 2': {'Study': -0.4, 'Fall asleep': 0.0}, 'Class 3': {'Study': 2.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': -1.14157619136, 'Close Facebook': -1.968007287168}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.4591836734693877, 'Go on Facebook': 0.5408163265306123}, 'Class 2': {'Study': 0.4591836734693877, 'Fall asleep': 0.5408163265306123}, 'Class 3': {'Study': 0.5408163265306123, 'Go to the pub': 0.4591836734693877}, 'Facebook': {'Keep scrolling': 0.5408163265306123, 'Close Facebook': 0.4591836734693877}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.9183673469387754
# =========================== EPISODE   6 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.4757120000000001, 'Go on Facebook': -1.1113274304000003}, 'Class 2': {'Study': -0.4, 'Fall asleep': 0.0}, 'Class 3': {'Study': 2.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': -1.14157619136, 'Close Facebook': -1.968007287168}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.44897959183673464, 'Go on Facebook': 0.5510204081632654}, 'Class 2': {'Study': 0.44897959183673464, 'Fall asleep': 0.5510204081632654}, 'Class 3': {'Study': 0.5510204081632654, 'Go to the pub': 0.44897959183673464}, 'Facebook': {'Keep scrolling': 0.5510204081632654, 'Close Facebook': 0.44897959183673464}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.8979591836734693
# =========================== EPISODE   7 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.5805696, 'Go on Facebook': -1.1113274304000003}, 'Class 2': {'Study': -0.4, 'Fall asleep': 0.0}, 'Class 3': {'Study': 2.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': -1.14157619136, 'Close Facebook': -1.968007287168}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.43877551020408156, 'Go on Facebook': 0.5612244897959184}, 'Class 2': {'Study': 0.43877551020408156, 'Fall asleep': 0.5612244897959184}, 'Class 3': {'Study': 0.5612244897959184, 'Go to the pub': 0.43877551020408156}, 'Facebook': {'Keep scrolling': 0.5612244897959184, 'Close Facebook': 0.43877551020408156}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.8775510204081631
# =========================== EPISODE   8 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 2     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 3     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 4     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.66445568, 'Go on Facebook': -1.2945456587648003}, 'Class 2': {'Study': -0.4, 'Fall asleep': 0.0}, 'Class 3': {'Study': 2.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': -1.3187446675328, 'Close Facebook': -2.207424048312064}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.4285714285714285, 'Go on Facebook': 0.5714285714285715}, 'Class 2': {'Study': 0.4285714285714285, 'Fall asleep': 0.5714285714285715}, 'Class 3': {'Study': 0.5714285714285715, 'Go to the pub': 0.4285714285714285}, 'Facebook': {'Keep scrolling': 0.5714285714285715, 'Close Facebook': 0.4285714285714285}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.857142857142857
# =========================== EPISODE   9 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.731564544, 'Go on Facebook': -1.2945456587648003}, 'Class 2': {'Study': -0.4, 'Fall asleep': 0.0}, 'Class 3': {'Study': 2.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': -1.3187446675328, 'Close Facebook': -2.207424048312064}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.4183673469387754, 'Go on Facebook': 0.5816326530612246}, 'Class 2': {'Study': 0.4183673469387754, 'Fall asleep': 0.5816326530612246}, 'Class 3': {'Study': 0.5816326530612246, 'Go to the pub': 0.4183673469387754}, 'Facebook': {'Keep scrolling': 0.5816326530612246, 'Close Facebook': 0.4183673469387754}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.8367346938775508
# =========================== EPISODE  10 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.7852516352, 'Go on Facebook': -1.2945456587648003}, 'Class 2': {'Study': -0.36, 'Fall asleep': 0.0}, 'Class 3': {'Study': 3.6, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': -1.3187446675328, 'Close Facebook': -2.207424048312064}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.40816326530612235, 'Go on Facebook': 0.5918367346938777}, 'Class 2': {'Study': 0.40816326530612235, 'Fall asleep': 0.5918367346938777}, 'Class 3': {'Study': 0.5918367346938777, 'Go to the pub': 0.40816326530612235}, 'Facebook': {'Keep scrolling': 0.5918367346938777, 'Close Facebook': 0.40816326530612235}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.8163265306122447
# =========================== EPISODE  11 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 2     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 3     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 4     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 5     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 6     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 7     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 8     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.8282013081600001, 'Go on Facebook': -1.6157824938900993}, 'Class 2': {'Study': -0.36, 'Fall asleep': 0.0}, 'Class 3': {'Study': 3.6, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': -1.8292719311245311, 'Close Facebook': -2.635705761492094}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.3979591836734693, 'Go on Facebook': 0.6020408163265307}, 'Class 2': {'Study': 0.3979591836734693, 'Fall asleep': 0.6020408163265307}, 'Class 3': {'Study': 0.6020408163265307, 'Go to the pub': 0.3979591836734693}, 'Facebook': {'Keep scrolling': 0.6020408163265307, 'Close Facebook': 0.3979591836734693}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.7959183673469385
# =========================== EPISODE  12 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 2     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 3     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 4     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 5     | Class 3  | Study          | 10.0   | Pass       | False |
# | 6     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.862561046528, 'Go on Facebook': -1.821894942714495}, 'Class 2': {'Study': -0.039999999999999925, 'Fall asleep': 0.0}, 'Class 3': {'Study': 4.880000000000001, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': -1.9926864925020404, 'Close Facebook': -2.8365056988822843}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.3877551020408162, 'Go on Facebook': 0.6122448979591838}, 'Class 2': {'Study': 0.3877551020408162, 'Fall asleep': 0.6122448979591838}, 'Class 3': {'Study': 0.6122448979591838, 'Go to the pub': 0.3877551020408162}, 'Facebook': {'Keep scrolling': 0.6122448979591838, 'Close Facebook': 0.3877551020408162}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.7755102040816324
# =========================== EPISODE  13 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 2     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 3     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.8900488372224, 'Go on Facebook': -2.0161995228219634}, 'Class 2': {'Study': -0.039999999999999925, 'Fall asleep': 0.0}, 'Class 3': {'Study': 4.880000000000001, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': -1.9926864925020404, 'Close Facebook': -3.0044655474808675}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.6224489795918369, 'Go on Facebook': 0.37755102040816313}, 'Class 2': {'Study': 0.37755102040816313, 'Fall asleep': 0.6224489795918369}, 'Class 3': {'Study': 0.6224489795918369, 'Go to the pub': 0.37755102040816313}, 'Facebook': {'Keep scrolling': 0.6224489795918369, 'Close Facebook': 0.37755102040816313}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.7551020408163263
# =========================== EPISODE  14 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 2     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 3     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 4     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 5     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 6     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 7     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.91203906977792, 'Go on Facebook': -2.171643186907938}, 'Class 2': {'Study': -0.039999999999999925, 'Fall asleep': 0.0}, 'Class 3': {'Study': 4.880000000000001, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': -2.6143089735459606, 'Close Facebook': -3.143781228684726}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.6326530612244899, 'Go on Facebook': 0.36734693877551006}, 'Class 2': {'Study': 0.36734693877551006, 'Fall asleep': 0.6326530612244899}, 'Class 3': {'Study': 0.6326530612244899, 'Go to the pub': 0.36734693877551006}, 'Facebook': {'Keep scrolling': 0.6326530612244899, 'Close Facebook': 0.36734693877551006}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.7346938775510201
# =========================== EPISODE  15 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.9296312558223359, 'Go on Facebook': -2.171643186907938}, 'Class 2': {'Study': -0.039999999999999925, 'Fall asleep': 0.0}, 'Class 3': {'Study': 4.880000000000001, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': -2.6143089735459606, 'Close Facebook': -3.143781228684726}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.642857142857143, 'Go on Facebook': 0.357142857142857}, 'Class 2': {'Study': 0.357142857142857, 'Fall asleep': 0.642857142857143}, 'Class 3': {'Study': 0.642857142857143, 'Go to the pub': 0.357142857142857}, 'Facebook': {'Keep scrolling': 0.642857142857143, 'Close Facebook': 0.357142857142857}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.714285714285714
# =========================== EPISODE  16 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.9437050046578688, 'Go on Facebook': -2.171643186907938}, 'Class 2': {'Study': -0.039999999999999925, 'Fall asleep': 0.0}, 'Class 3': {'Study': 4.880000000000001, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': -2.6143089735459606, 'Close Facebook': -3.143781228684726}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.6530612244897961, 'Go on Facebook': 0.3469387755102039}, 'Class 2': {'Study': 0.3469387755102039, 'Fall asleep': 0.6530612244897961}, 'Class 3': {'Study': 0.6530612244897961, 'Go to the pub': 0.3469387755102039}, 'Facebook': {'Keep scrolling': 0.6530612244897961, 'Close Facebook': 0.3469387755102039}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.6938775510204078
# =========================== EPISODE  17 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 2     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 3     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.954964003726295, 'Go on Facebook': -2.4078901647646234}, 'Class 2': {'Study': -0.039999999999999925, 'Fall asleep': 0.0}, 'Class 3': {'Study': 4.880000000000001, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': -2.6143089735459606, 'Close Facebook': -3.264891883786197}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.6632653061224492, 'Go on Facebook': 0.33673469387755084}, 'Class 2': {'Study': 0.33673469387755084, 'Fall asleep': 0.6632653061224492}, 'Class 3': {'Study': 0.6632653061224492, 'Go to the pub': 0.33673469387755084}, 'Facebook': {'Keep scrolling': 0.6632653061224492, 'Close Facebook': 0.33673469387755084}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.6734693877551017
# =========================== EPISODE  18 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.963971202981036, 'Go on Facebook': -2.4078901647646234}, 'Class 2': {'Study': -0.039999999999999925, 'Fall asleep': 0.0}, 'Class 3': {'Study': 4.880000000000001, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': -2.6143089735459606, 'Close Facebook': -3.264891883786197}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.6734693877551022, 'Go on Facebook': 0.32653061224489777}, 'Class 2': {'Study': 0.32653061224489777, 'Fall asleep': 0.6734693877551022}, 'Class 3': {'Study': 0.6734693877551022, 'Go to the pub': 0.32653061224489777}, 'Facebook': {'Keep scrolling': 0.6734693877551022, 'Close Facebook': 0.32653061224489777}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.6530612244897955
# =========================== EPISODE  19 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.9711769623848288, 'Go on Facebook': -2.4078901647646234}, 'Class 2': {'Study': -0.039999999999999925, 'Fall asleep': 0.0}, 'Class 3': {'Study': 4.880000000000001, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': -2.6143089735459606, 'Close Facebook': -3.264891883786197}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.6836734693877553, 'Go on Facebook': 0.3163265306122447}, 'Class 2': {'Study': 0.3163265306122447, 'Fall asleep': 0.6836734693877553}, 'Class 3': {'Study': 0.6836734693877553, 'Go to the pub': 0.3163265306122447}, 'Facebook': {'Keep scrolling': 0.6836734693877553, 'Close Facebook': 0.3163265306122447}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.6326530612244894
# =========================== EPISODE  20 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.976941569907863, 'Go on Facebook': -2.4078901647646234}, 'Class 2': {'Study': -0.039999999999999925, 'Fall asleep': 0.0}, 'Class 3': {'Study': 4.880000000000001, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': -2.6143089735459606, 'Close Facebook': -3.264891883786197}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.6938775510204084, 'Go on Facebook': 0.3061224489795916}, 'Class 2': {'Study': 0.3061224489795916, 'Fall asleep': 0.6938775510204084}, 'Class 3': {'Study': 0.6938775510204084, 'Go to the pub': 0.3061224489795916}, 'Facebook': {'Keep scrolling': 0.6938775510204084, 'Close Facebook': 0.3061224489795916}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.6122448979591832
# =========================== EPISODE  21 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.9815532559262903, 'Go on Facebook': -2.4078901647646234}, 'Class 2': {'Study': -0.039999999999999925, 'Fall asleep': 0.0}, 'Class 3': {'Study': 4.880000000000001, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': -2.6143089735459606, 'Close Facebook': -3.264891883786197}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.7040816326530615, 'Go on Facebook': 0.29591836734693855}, 'Class 2': {'Study': 0.29591836734693855, 'Fall asleep': 0.7040816326530615}, 'Class 3': {'Study': 0.7040816326530615, 'Go to the pub': 0.29591836734693855}, 'Facebook': {'Keep scrolling': 0.7040816326530615, 'Close Facebook': 0.29591836734693855}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.5918367346938771
# =========================== EPISODE  22 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.9852426047410323, 'Go on Facebook': -2.4078901647646234}, 'Class 2': {'Study': -0.039999999999999925, 'Fall asleep': 0.0}, 'Class 3': {'Study': 4.880000000000001, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': -2.6143089735459606, 'Close Facebook': -3.264891883786197}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.7142857142857145, 'Go on Facebook': 0.2857142857142855}, 'Class 2': {'Study': 0.2857142857142855, 'Fall asleep': 0.7142857142857145}, 'Class 3': {'Study': 0.7142857142857145, 'Go to the pub': 0.2857142857142855}, 'Facebook': {'Keep scrolling': 0.7142857142857145, 'Close Facebook': 0.2857142857142855}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.571428571428571
# =========================== EPISODE  23 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.9881940837928258, 'Go on Facebook': -2.4078901647646234}, 'Class 2': {'Study': -0.039999999999999925, 'Fall asleep': 0.0}, 'Class 3': {'Study': 4.880000000000001, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': -2.6143089735459606, 'Close Facebook': -3.264891883786197}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.7244897959183676, 'Go on Facebook': 0.2755102040816324}, 'Class 2': {'Study': 0.2755102040816324, 'Fall asleep': 0.7244897959183676}, 'Class 3': {'Study': 0.7244897959183676, 'Go to the pub': 0.2755102040816324}, 'Facebook': {'Keep scrolling': 0.7244897959183676, 'Close Facebook': 0.2755102040816324}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.5510204081632648
# =========================== EPISODE  24 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.9905552670342606, 'Go on Facebook': -2.4078901647646234}, 'Class 2': {'Study': -0.039999999999999925, 'Fall asleep': 0.0}, 'Class 3': {'Study': 4.880000000000001, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': -2.6143089735459606, 'Close Facebook': -3.264891883786197}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.7346938775510207, 'Go on Facebook': 0.26530612244897933}, 'Class 2': {'Study': 0.26530612244897933, 'Fall asleep': 0.7346938775510207}, 'Class 3': {'Study': 0.7346938775510207, 'Go to the pub': 0.26530612244897933}, 'Facebook': {'Keep scrolling': 0.7346938775510207, 'Close Facebook': 0.26530612244897933}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.5306122448979587
# =========================== EPISODE  25 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 2     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 3     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 4     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 5     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 6     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 7     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 8     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 9     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 10    | Class 1  | Study          | -2.0   | Class 2    | False |
# | 11    | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.9924442136274085, 'Go on Facebook': -2.875815848480807}, 'Class 2': {'Study': -0.039999999999999925, 'Fall asleep': 0.0}, 'Class 3': {'Study': 4.880000000000001, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': -3.4574418768000736, 'Close Facebook': -3.4544707121422666}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.7448979591836737, 'Go on Facebook': 0.25510204081632626}, 'Class 2': {'Study': 0.25510204081632626, 'Fall asleep': 0.7448979591836737}, 'Class 3': {'Study': 0.7448979591836737, 'Go to the pub': 0.25510204081632626}, 'Facebook': {'Keep scrolling': 0.25510204081632626, 'Close Facebook': 0.7448979591836737}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.5102040816326525
# =========================== EPISODE  26 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.9939553709019269, 'Go on Facebook': -2.875815848480807}, 'Class 2': {'Study': -0.039999999999999925, 'Fall asleep': 0.0}, 'Class 3': {'Study': 4.880000000000001, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': -3.4574418768000736, 'Close Facebook': -3.4544707121422666}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.7551020408163268, 'Go on Facebook': 0.2448979591836732}, 'Class 2': {'Study': 0.2448979591836732, 'Fall asleep': 0.7551020408163268}, 'Class 3': {'Study': 0.7551020408163268, 'Go to the pub': 0.2448979591836732}, 'Facebook': {'Keep scrolling': 0.2448979591836732, 'Close Facebook': 0.7551020408163268}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.4897959183673464
# =========================== EPISODE  27 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 2     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 3     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 4     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 5     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 6     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 7     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 8     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.9951642967215415, 'Go on Facebook': -3.478583908544186}, 'Class 2': {'Study': -0.039999999999999925, 'Fall asleep': 0.0}, 'Class 3': {'Study': 4.880000000000001, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': -3.588293039264072, 'Close Facebook': -3.6204342035169668}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.7653061224489799, 'Go on Facebook': 0.2346938775510201}, 'Class 2': {'Study': 0.2346938775510201, 'Fall asleep': 0.7653061224489799}, 'Class 3': {'Study': 0.7653061224489799, 'Go to the pub': 0.2346938775510201}, 'Facebook': {'Keep scrolling': 0.7653061224489799, 'Close Facebook': 0.2346938775510201}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.4693877551020402
# =========================== EPISODE  28 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.9961314373772332, 'Go on Facebook': -3.478583908544186}, 'Class 2': {'Study': -0.039999999999999925, 'Fall asleep': 0.0}, 'Class 3': {'Study': 4.880000000000001, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': -3.588293039264072, 'Close Facebook': -3.6204342035169668}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.775510204081633, 'Go on Facebook': 0.22448979591836704}, 'Class 2': {'Study': 0.22448979591836704, 'Fall asleep': 0.775510204081633}, 'Class 3': {'Study': 0.775510204081633, 'Go to the pub': 0.22448979591836704}, 'Facebook': {'Keep scrolling': 0.775510204081633, 'Close Facebook': 0.22448979591836704}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.4489795918367341
# =========================== EPISODE  29 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 2     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 3     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 4     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.9969051499017865, 'Go on Facebook': -3.628759873902882}, 'Class 2': {'Study': -0.039999999999999925, 'Fall asleep': 0.0}, 'Class 3': {'Study': 4.880000000000001, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': -3.716527178478791, 'Close Facebook': -3.6556510215414755}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.785714285714286, 'Go on Facebook': 0.21428571428571397}, 'Class 2': {'Study': 0.21428571428571397, 'Fall asleep': 0.785714285714286}, 'Class 3': {'Study': 0.785714285714286, 'Go to the pub': 0.21428571428571397}, 'Facebook': {'Keep scrolling': 0.21428571428571397, 'Close Facebook': 0.785714285714286}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.42857142857142794
# =========================== EPISODE  30 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 2     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 3     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 4     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 5     | Class 3  | Go to the pub  |  1.0   | Pub        | False |
# | 6     | Pub      | Have a pint    | -2.0   | Class 2    | False |
# | 7     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 8     | Class 3  | Go to the pub  |  1.0   | Pub        | False |
# | 9     | Pub      | Have a pint    | -2.0   | Class 2    | False |
# | 10    | Class 2  | Study          | -2.0   | Class 3    | False |
# | 11    | Class 3  | Study          | 10.0   | Pass       | False |
# | 12    | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.997524119921429, 'Go on Facebook': -3.7610250829997716}, 'Class 2': {'Study': 1.1468160000000007, 'Fall asleep': 0.0}, 'Class 3': {'Study': 5.904000000000001, 'Go to the pub': 0.30246336}, 'Facebook': {'Keep scrolling': -3.8312389266604985, 'Close Facebook': -3.683963744215502}, 'Pub': {'Have a pint': -0.5053247999999999}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.7959183673469391, 'Go on Facebook': 0.2040816326530609}, 'Class 2': {'Study': 0.7959183673469391, 'Fall asleep': 0.2040816326530609}, 'Class 3': {'Study': 0.7959183673469391, 'Go to the pub': 0.2040816326530609}, 'Facebook': {'Keep scrolling': 0.2040816326530609, 'Close Facebook': 0.7959183673469391}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.4081632653061218
# =========================== EPISODE  31 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 2     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 3     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.791592415937143, 'Go on Facebook': -3.8719335403586075}, 'Class 2': {'Study': 1.1468160000000007, 'Fall asleep': 0.0}, 'Class 3': {'Study': 5.904000000000001, 'Go to the pub': 0.30246336}, 'Facebook': {'Keep scrolling': -3.8312389266604985, 'Close Facebook': -3.7067253369582587}, 'Pub': {'Have a pint': -0.5053247999999999}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.8061224489795922, 'Go on Facebook': 0.19387755102040782}, 'Class 2': {'Study': 0.8061224489795922, 'Fall asleep': 0.19387755102040782}, 'Class 3': {'Study': 0.8061224489795922, 'Go to the pub': 0.19387755102040782}, 'Facebook': {'Keep scrolling': 0.19387755102040782, 'Close Facebook': 0.8061224489795922}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.38775510204081565
# =========================== EPISODE  32 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.6268470527497143, 'Go on Facebook': -3.8719335403586075}, 'Class 2': {'Study': 1.5801728000000008, 'Fall asleep': 0.0}, 'Class 3': {'Study': 6.7232, 'Go to the pub': 0.30246336}, 'Facebook': {'Keep scrolling': -3.8312389266604985, 'Close Facebook': -3.7067253369582587}, 'Pub': {'Have a pint': -0.5053247999999999}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.8163265306122452, 'Go on Facebook': 0.18367346938775475}, 'Class 2': {'Study': 0.8163265306122452, 'Fall asleep': 0.18367346938775475}, 'Class 3': {'Study': 0.8163265306122452, 'Go to the pub': 0.18367346938775475}, 'Facebook': {'Keep scrolling': 0.18367346938775475, 'Close Facebook': 0.8163265306122452}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.3673469387755095
# =========================== EPISODE  33 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.4170465381997712, 'Go on Facebook': -3.8719335403586075}, 'Class 2': {'Study': 2.0743142400000005, 'Fall asleep': 0.0}, 'Class 3': {'Study': 7.37856, 'Go to the pub': 0.30246336}, 'Facebook': {'Keep scrolling': -3.8312389266604985, 'Close Facebook': -3.7067253369582587}, 'Pub': {'Have a pint': -0.5053247999999999}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.8265306122448983, 'Go on Facebook': 0.17346938775510168}, 'Class 2': {'Study': 0.8265306122448983, 'Fall asleep': 0.17346938775510168}, 'Class 3': {'Study': 0.8265306122448983, 'Go to the pub': 0.17346938775510168}, 'Facebook': {'Keep scrolling': 0.17346938775510168, 'Close Facebook': 0.8265306122448983}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.34693877551020336
# =========================== EPISODE  34 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Go to the pub  |  1.0   | Pub        | False |
# | 3     | Pub      | Have a pint    | -2.0   | Class 3    | False |
# | 4     | Class 3  | Study          | 10.0   | Pass       | False |
# | 5     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.1602606673598168, 'Go on Facebook': -3.8719335403586075}, 'Class 2': {'Study': 2.5875921920000007, 'Fall asleep': 0.0}, 'Class 3': {'Study': 7.9028480000000005, 'Go to the pub': 0.35101222400000004}, 'Facebook': {'Keep scrolling': -3.8312389266604985, 'Close Facebook': -3.7067253369582587}, 'Pub': {'Have a pint': 0.5238809600000001}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.8367346938775514, 'Go on Facebook': 0.1632653061224486}, 'Class 2': {'Study': 0.8367346938775514, 'Fall asleep': 0.1632653061224486}, 'Class 3': {'Study': 0.8367346938775514, 'Go to the pub': 0.1632653061224486}, 'Facebook': {'Keep scrolling': 0.1632653061224486, 'Close Facebook': 0.8367346938775514}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.3265306122448972
# =========================== EPISODE  35 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Go to the pub  |  1.0   | Pub        | False |
# | 3     | Pub      | Have a pint    | -2.0   | Class 3    | False |
# | 4     | Class 3  | Study          | 10.0   | Pass       | False |
# | 5     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -0.8624419393278533, 'Go on Facebook': -3.8719335403586075}, 'Class 2': {'Study': 3.0925863936000004, 'Fall asleep': 0.0}, 'Class 3': {'Study': 8.3222784, 'Go to the pub': 0.575108352}, 'Facebook': {'Keep scrolling': -3.8312389266604985, 'Close Facebook': -3.7067253369582587}, 'Pub': {'Have a pint': 1.4416174080000004}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.8469387755102045, 'Go on Facebook': 0.15306122448979553}, 'Class 2': {'Study': 0.8469387755102045, 'Fall asleep': 0.15306122448979553}, 'Class 3': {'Study': 0.8469387755102045, 'Go to the pub': 0.15306122448979553}, 'Facebook': {'Keep scrolling': 0.15306122448979553, 'Close Facebook': 0.8469387755102045}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.30612244897959107
# =========================== EPISODE  36 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 2     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 3     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 4     | Class 3  | Study          | 10.0   | Pass       | False |
# | 5     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -0.5332880006142825, 'Go on Facebook': -3.9647573929393727}, 'Class 2': {'Study': 3.5720792268800006, 'Fall asleep': 0.0}, 'Class 3': {'Study': 8.65782272, 'Go to the pub': 0.575108352}, 'Facebook': {'Keep scrolling': -3.8312389266604985, 'Close Facebook': -3.5206198186456206}, 'Pub': {'Have a pint': 1.4416174080000004}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.8571428571428575, 'Go on Facebook': 0.14285714285714246}, 'Class 2': {'Study': 0.8571428571428575, 'Fall asleep': 0.14285714285714246}, 'Class 3': {'Study': 0.8571428571428575, 'Go to the pub': 0.14285714285714246}, 'Facebook': {'Keep scrolling': 0.14285714285714246, 'Close Facebook': 0.8571428571428575}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# ...
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 0.5362994192024158, 'Go on Facebook': -3.9647573929393727}, 'Class 2': {'Study': 4.781048096194561, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.31280523264, 'Go to the pub': 0.575108352}, 'Facebook': {'Keep scrolling': -3.8312389266604985, 'Close Facebook': -3.5206198186456206}, 'Pub': {'Have a pint': 1.4416174080000004}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.8877551020408168, 'Go on Facebook': 0.11224489795918327}, 'Class 2': {'Study': 0.8877551020408168, 'Fall asleep': 0.11224489795918327}, 'Class 3': {'Study': 0.8877551020408168, 'Go to the pub': 0.11224489795918327}, 'Facebook': {'Keep scrolling': 0.11224489795918327, 'Close Facebook': 0.8877551020408168}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.22448979591836654
# =========================== EPISODE  40 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Go to the pub  |  1.0   | Pub        | False |
# | 3     | Pub      | Have a pint    | -2.0   | Class 3    | False |
# | 4     | Class 3  | Study          | 10.0   | Pass       | False |
# | 5     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 0.8896281926769536, 'Go on Facebook': -3.9647573929393727}, 'Class 2': {'Study': 5.101143418830849, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.450244186112, 'Go to the pub': 0.91957781504}, 'Facebook': {'Keep scrolling': -3.8312389266604985, 'Close Facebook': -3.5206198186456206}, 'Pub': {'Have a pint': 2.4295988682752006}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.8979591836734697, 'Go on Facebook': 0.10204081632653021}, 'Class 2': {'Study': 0.8979591836734697, 'Fall asleep': 0.10204081632653021}, 'Class 3': {'Study': 0.8979591836734697, 'Go to the pub': 0.10204081632653021}, 'Facebook': {'Keep scrolling': 0.10204081632653021, 'Close Facebook': 0.8979591836734697}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.20408163265306042
# =========================== EPISODE  41 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Go to the pub  |  1.0   | Pub        | False |
# | 3     | Pub      | Have a pint    | -2.0   | Class 3    | False |
# | 4     | Class 3  | Study          | 10.0   | Pass       | False |
# | 5     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 1.2299083695311155, 'Go on Facebook': -3.9647573929393727}, 'Class 2': {'Study': 5.381958688564839, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.5601953488896, 'Go to the pub': 1.3729900483215363}, 'Facebook': {'Keep scrolling': -3.8312389266604985, 'Close Facebook': -3.5206198186456206}, 'Pub': {'Have a pint': 3.2447230481203206}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.9081632653061229, 'Go on Facebook': 0.09183673469387715}, 'Class 2': {'Study': 0.9081632653061229, 'Fall asleep': 0.09183673469387715}, 'Class 3': {'Study': 0.9081632653061229, 'Go to the pub': 0.09183673469387715}, 'Facebook': {'Keep scrolling': 0.09183673469387715, 'Close Facebook': 0.9081632653061229}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.1836734693877543
# =========================== EPISODE  42 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 2     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 3     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 4     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 5     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 6     | Class 3  | Study          | 10.0   | Pass       | False |
# | 7     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 1.5526792595665635, 'Go on Facebook': -3.943534208078329}, 'Class 2': {'Study': 5.6264021136519995, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.64815627911168, 'Go to the pub': 1.3729900483215363}, 'Facebook': {'Keep scrolling': -3.8312389266604985, 'Close Facebook': -2.5747063722051156}, 'Pub': {'Have a pint': 3.2447230481203206}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.918367346938776, 'Go on Facebook': 0.0816326530612241}, 'Class 2': {'Study': 0.918367346938776, 'Fall asleep': 0.0816326530612241}, 'Class 3': {'Study': 0.918367346938776, 'Go to the pub': 0.0816326530612241}, 'Facebook': {'Keep scrolling': 0.0816326530612241, 'Close Facebook': 0.918367346938776}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.1632653061224482
# =========================== EPISODE  43 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 1.8548957881106107, 'Go on Facebook': -3.943534208078329}, 'Class 2': {'Study': 5.837789821161702, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.718525023289343, 'Go to the pub': 1.3729900483215363}, 'Facebook': {'Keep scrolling': -3.8312389266604985, 'Close Facebook': -2.5747063722051156}, 'Pub': {'Have a pint': 3.2447230481203206}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.9285714285714289, 'Go on Facebook': 0.07142857142857104}, 'Class 2': {'Study': 0.9285714285714289, 'Fall asleep': 0.07142857142857104}, 'Class 3': {'Study': 0.9285714285714289, 'Go to the pub': 0.07142857142857104}, 'Facebook': {'Keep scrolling': 0.07142857142857104, 'Close Facebook': 0.9285714285714289}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.14285714285714207
# =========================== EPISODE  44 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 2.134718798297595, 'Go on Facebook': -3.943534208078329}, 'Class 2': {'Study': 6.019566361121443, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.774820018631475, 'Go to the pub': 1.3729900483215363}, 'Facebook': {'Keep scrolling': -3.8312389266604985, 'Close Facebook': -2.5747063722051156}, 'Pub': {'Have a pint': 3.2447230481203206}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.938775510204082, 'Go on Facebook': 0.06122448979591798}, 'Class 2': {'Study': 0.938775510204082, 'Fall asleep': 0.06122448979591798}, 'Class 3': {'Study': 0.938775510204082, 'Go to the pub': 0.06122448979591798}, 'Facebook': {'Keep scrolling': 0.06122448979591798, 'Close Facebook': 0.938775510204082}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.12244897959183595
# =========================== EPISODE  45 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 2.391296983639936, 'Go on Facebook': -3.943534208078329}, 'Class 2': {'Study': 6.17512069225082, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.81985601490518, 'Go to the pub': 1.3729900483215363}, 'Facebook': {'Keep scrolling': -3.8312389266604985, 'Close Facebook': -2.5747063722051156}, 'Pub': {'Have a pint': 3.2447230481203206}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.9489795918367351, 'Go on Facebook': 0.05102040816326492}, 'Class 2': {'Study': 0.9489795918367351, 'Fall asleep': 0.05102040816326492}, 'Class 3': {'Study': 0.9489795918367351, 'Go to the pub': 0.05102040816326492}, 'Facebook': {'Keep scrolling': 0.05102040816326492, 'Close Facebook': 0.9489795918367351}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.10204081632652984
# =========================== EPISODE  46 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 2.624559311517096, 'Go on Facebook': -3.943534208078329}, 'Class 2': {'Study': 6.307670636483588, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.855884811924145, 'Go to the pub': 1.3729900483215363}, 'Facebook': {'Keep scrolling': -3.8312389266604985, 'Close Facebook': -2.5747063722051156}, 'Pub': {'Have a pint': 3.2447230481203206}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.9591836734693882, 'Go on Facebook': 0.04081632653061186}, 'Class 2': {'Study': 0.9591836734693882, 'Fall asleep': 0.04081632653061186}, 'Class 3': {'Study': 0.9591836734693882, 'Go to the pub': 0.04081632653061186}, 'Facebook': {'Keep scrolling': 0.04081632653061186, 'Close Facebook': 0.9591836734693882}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.08163265306122372
# =========================== EPISODE  47 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 2.8350281637807226, 'Go on Facebook': -3.943534208078329}, 'Class 2': {'Study': 6.307670636483588, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.855884811924145, 'Go to the pub': 1.3729900483215363}, 'Facebook': {'Keep scrolling': -3.8312389266604985, 'Close Facebook': -2.5747063722051156}, 'Pub': {'Have a pint': 3.2447230481203206}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.9693877551020412, 'Go on Facebook': 0.0306122448979588}, 'Class 2': {'Study': 0.9693877551020412, 'Fall asleep': 0.0306122448979588}, 'Class 3': {'Study': 0.9693877551020412, 'Go to the pub': 0.0306122448979588}, 'Facebook': {'Keep scrolling': 0.0306122448979588, 'Close Facebook': 0.9693877551020412}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.0612244897959176
# =========================== EPISODE  48 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 3.003403245591624, 'Go on Facebook': -3.943534208078329}, 'Class 2': {'Study': 6.420195775333217, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.884707849539316, 'Go to the pub': 1.3729900483215363}, 'Facebook': {'Keep scrolling': -3.8312389266604985, 'Close Facebook': -2.5747063722051156}, 'Pub': {'Have a pint': 3.2447230481203206}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.9795918367346942, 'Go on Facebook': 0.020408163265305743}, 'Class 2': {'Study': 0.9795918367346942, 'Fall asleep': 0.020408163265305743}, 'Class 3': {'Study': 0.9795918367346942, 'Go to the pub': 0.020408163265305743}, 'Facebook': {'Keep scrolling': 0.020408163265305743, 'Close Facebook': 0.9795918367346942}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.040816326530611485
# =========================== EPISODE  49 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 3.1583578360332782, 'Go on Facebook': -3.943534208078329}, 'Class 2': {'Study': 6.515404033183651, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.907766279631453, 'Go to the pub': 1.3729900483215363}, 'Facebook': {'Keep scrolling': -3.8312389266604985, 'Close Facebook': -2.5747063722051156}, 'Pub': {'Have a pint': 3.2447230481203206}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 0.9897959183673473, 'Go on Facebook': 0.010204081632652682}, 'Class 2': {'Study': 0.9897959183673473, 'Fall asleep': 0.010204081632652682}, 'Class 3': {'Study': 0.9897959183673473, 'Go to the pub': 0.010204081632652682}, 'Facebook': {'Keep scrolling': 0.010204081632652682, 'Close Facebook': 0.9897959183673473}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0.020408163265305364
# =========================== EPISODE  50 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 3.2994589947996795, 'Go on Facebook': -3.943534208078329}, 'Class 2': {'Study': 6.5957211568805825, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.926213023705163, 'Go to the pub': 1.3729900483215363}, 'Facebook': {'Keep scrolling': -3.8312389266604985, 'Close Facebook': -2.5747063722051156}, 'Pub': {'Have a pint': 3.2447230481203206}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {}}
# Epsilon: 0

# %% [markdown]
# Try with $\gamma=0$ and different $\epsilon$ values
