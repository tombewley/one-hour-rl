# %% [markdown]
# # 3 | Policy Improvement: The Q-learning Algorithm
#
# Having evaluated our policy $\pi$, how can we go about obtaining a better one? This question is the heart of *policy improvement*, perhaps the fundamental concept of RL. Recall, when we performed policy evaluation we obtained the value of taking every action in every state. Thus, we can perform policy improvement readily by picking our current best estimate of the optimal action from each state -- so-called *greedy* action selection. Once we've obtained a new policy, we can evaluate it as before. Continually iterating between policy evaluation and policy improvement in this way, we are guarenteed to reach the optimal policy $\pi^*$ according to the policy improvement theorem.

# %%
from mdp import StudentMDP
mdp = StudentMDP(verbose=True)

# %%
from agent import QLearningAgent
agent = QLearningAgent(mdp, epsilon=1.0, alpha=0.2, gamma=0.9)

# %%
NUM_EPS = 50
mdp.ep = 0
while mdp.ep < NUM_EPS:
    state = mdp.reset()
    done = False
    while not done:
        action = agent.act(state)
        next_state, reward, done, info = mdp.step(action)
        agent.learn(state, action, reward, next_state, done)
        state = next_state

    print("Value function:")
    print(agent.Q)
    print("Policy:")
    print(agent.policy)
    print("Epsilon:", agent.epsilon)
    
    agent.epsilon = max(agent.epsilon - 1 / (NUM_EPS-1), 0)
# Out:
# =========================== EPISODE   1 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -0.4, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 0.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 0.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 0.0}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.5, 'Go on Facebook': 0.5}, 'Class 2': {'Study': 0.5, 'Fall asleep': 0.5}, 'Class 3': {'Study': 0.5, 'Go to the pub': 0.5}, 'Facebook': {'Keep scrolling': 0.5, 'Close Facebook': 0.5}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 1.0
# =========================== EPISODE   2 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 2     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 3     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -0.7200000000000001, 'Go on Facebook': -0.2}, 'Class 2': {'Study': 0.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 0.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': -0.43600000000000005}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.4897959183673469, 'Go on Facebook': 0.5102040816326531}, 'Class 2': {'Study': 0.5102040816326531, 'Fall asleep': 0.4897959183673469}, 'Class 3': {'Study': 0.5102040816326531, 'Go to the pub': 0.4897959183673469}, 'Facebook': {'Keep scrolling': 0.5102040816326531, 'Close Facebook': 0.4897959183673469}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.9795918367346939
# =========================== EPISODE   3 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -0.976, 'Go on Facebook': -0.2}, 'Class 2': {'Study': 0.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 0.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': -0.43600000000000005}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.47959183673469385, 'Go on Facebook': 0.5204081632653061}, 'Class 2': {'Study': 0.5204081632653061, 'Fall asleep': 0.47959183673469385}, 'Class 3': {'Study': 0.5204081632653061, 'Go to the pub': 0.47959183673469385}, 'Facebook': {'Keep scrolling': 0.5204081632653061, 'Close Facebook': 0.47959183673469385}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.9591836734693877
# =========================== EPISODE   4 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 2     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 3     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.1808, 'Go on Facebook': -0.36000000000000004}, 'Class 2': {'Study': 0.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 0.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': -0.8136000000000001}, 'Pub': {'Have a pint': 0.0}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.4693877551020408, 'Go on Facebook': 0.5306122448979592}, 'Class 2': {'Study': 0.5306122448979592, 'Fall asleep': 0.4693877551020408}, 'Class 3': {'Study': 0.5306122448979592, 'Go to the pub': 0.4693877551020408}, 'Facebook': {'Keep scrolling': 0.5306122448979592, 'Close Facebook': 0.4693877551020408}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.9387755102040816
# =========================== EPISODE   5 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Go to the pub  |  1.0   | Pub        | False |
# | 3     | Pub      | Have a pint    | -2.0   | Class 2    | False |
# | 4     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.34464, 'Go on Facebook': -0.36000000000000004}, 'Class 2': {'Study': -0.4, 'Fall asleep': 0.0}, 'Class 3': {'Study': 0.0, 'Go to the pub': 0.2}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': -0.8136000000000001}, 'Pub': {'Have a pint': -0.4}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.4591836734693877, 'Go on Facebook': 0.5408163265306123}, 'Class 2': {'Study': 0.4591836734693877, 'Fall asleep': 0.5408163265306123}, 'Class 3': {'Study': 0.4591836734693877, 'Go to the pub': 0.5408163265306123}, 'Facebook': {'Keep scrolling': 0.5408163265306123, 'Close Facebook': 0.4591836734693877}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.9183673469387754
# =========================== EPISODE   6 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 2     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 3     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 4     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 5     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 6     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 7     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 8     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 9     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 10    | Class 1  | Study          | -2.0   | Class 2    | False |
# | 11    | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.4757120000000001, 'Go on Facebook': -0.5904}, 'Class 2': {'Study': -0.4, 'Fall asleep': 0.0}, 'Class 3': {'Study': 0.0, 'Go to the pub': 0.2}, 'Facebook': {'Keep scrolling': -1.14157619136, 'Close Facebook': -1.4172480000000003}, 'Pub': {'Have a pint': -0.4}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.44897959183673464, 'Go on Facebook': 0.5510204081632654}, 'Class 2': {'Study': 0.44897959183673464, 'Fall asleep': 0.5510204081632654}, 'Class 3': {'Study': 0.44897959183673464, 'Go to the pub': 0.5510204081632654}, 'Facebook': {'Keep scrolling': 0.5510204081632654, 'Close Facebook': 0.44897959183673464}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.8979591836734693
# =========================== EPISODE   7 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 2     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 3     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 4     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 5     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 6     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 7     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 8     | Class 3  | Go to the pub  |  1.0   | Pub        | False |
# | 9     | Pub      | Have a pint    | -2.0   | Class 3    | False |
# | 10    | Class 3  | Go to the pub  |  1.0   | Pub        | False |
# | 11    | Pub      | Have a pint    | -2.0   | Class 2    | False |
# | 12    | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.5805696, 'Go on Facebook': -1.170869530908626}, 'Class 2': {'Study': -0.6839999999999999, 'Fall asleep': 0.0}, 'Class 3': {'Study': 0.0, 'Go to the pub': 0.31013119999999994}, 'Facebook': {'Keep scrolling': -1.492369774182144, 'Close Facebook': -1.964198970443604}, 'Pub': {'Have a pint': -0.934528}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.43877551020408156, 'Go on Facebook': 0.5612244897959184}, 'Class 2': {'Study': 0.43877551020408156, 'Fall asleep': 0.5612244897959184}, 'Class 3': {'Study': 0.43877551020408156, 'Go to the pub': 0.5612244897959184}, 'Facebook': {'Keep scrolling': 0.5612244897959184, 'Close Facebook': 0.43877551020408156}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.8775510204081631
# =========================== EPISODE   8 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 2     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 3     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.66445568, 'Go on Facebook': -1.4053221840796868}, 'Class 2': {'Study': -0.6839999999999999, 'Fall asleep': 0.0}, 'Class 3': {'Study': 0.0, 'Go to the pub': 0.31013119999999994}, 'Facebook': {'Keep scrolling': -1.492369774182144, 'Close Facebook': -2.2243171694892268}, 'Pub': {'Have a pint': -0.934528}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.4285714285714285, 'Go on Facebook': 0.5714285714285715}, 'Class 2': {'Study': 0.4285714285714285, 'Fall asleep': 0.5714285714285715}, 'Class 3': {'Study': 0.4285714285714285, 'Go to the pub': 0.5714285714285715}, 'Facebook': {'Keep scrolling': 0.5714285714285715, 'Close Facebook': 0.4285714285714285}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.857142857142857
# =========================== EPISODE   9 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.731564544, 'Go on Facebook': -1.4053221840796868}, 'Class 2': {'Study': -0.891376384, 'Fall asleep': 0.0}, 'Class 3': {'Study': 2.0, 'Go to the pub': 0.31013119999999994}, 'Facebook': {'Keep scrolling': -1.492369774182144, 'Close Facebook': -2.2243171694892268}, 'Pub': {'Have a pint': -0.934528}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.4183673469387754, 'Go on Facebook': 0.5816326530612246}, 'Class 2': {'Study': 0.4183673469387754, 'Fall asleep': 0.5816326530612246}, 'Class 3': {'Study': 0.5816326530612246, 'Go to the pub': 0.4183673469387754}, 'Facebook': {'Keep scrolling': 0.5816326530612246, 'Close Facebook': 0.4183673469387754}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.8367346938775508
# =========================== EPISODE  10 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 2     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 3     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 4     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 5     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 6     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 7     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 8     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 9     | Class 3  | Go to the pub  |  1.0   | Pub        | False |
# | 10    | Pub      | Have a pint    | -2.0   | Class 2    | False |
# | 11    | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.7852516352, 'Go on Facebook': -1.8936012318825415}, 'Class 2': {'Study': -0.7531011072, 'Fall asleep': 0.0}, 'Class 3': {'Study': 2.0, 'Go to the pub': 0.27988991999999996}, 'Facebook': {'Keep scrolling': -1.662522378698501, 'Close Facebook': -2.859377575156709}, 'Pub': {'Have a pint': -1.1476224}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.5918367346938777, 'Go on Facebook': 0.40816326530612235}, 'Class 2': {'Study': 0.40816326530612235, 'Fall asleep': 0.5918367346938777}, 'Class 3': {'Study': 0.5918367346938777, 'Go to the pub': 0.40816326530612235}, 'Facebook': {'Keep scrolling': 0.5918367346938777, 'Close Facebook': 0.40816326530612235}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.8163265306122447
# =========================== EPISODE  11 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.8282013081600001, 'Go on Facebook': -1.8936012318825415}, 'Class 2': {'Study': -0.64248088576, 'Fall asleep': 0.0}, 'Class 3': {'Study': 3.6, 'Go to the pub': 0.27988991999999996}, 'Facebook': {'Keep scrolling': -1.662522378698501, 'Close Facebook': -2.859377575156709}, 'Pub': {'Have a pint': -1.1476224}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.6020408163265307, 'Go on Facebook': 0.3979591836734693}, 'Class 2': {'Study': 0.3979591836734693, 'Fall asleep': 0.6020408163265307}, 'Class 3': {'Study': 0.6020408163265307, 'Go to the pub': 0.3979591836734693}, 'Facebook': {'Keep scrolling': 0.6020408163265307, 'Close Facebook': 0.3979591836734693}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.7959183673469385
# =========================== EPISODE  12 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 2     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 3     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.862561046528, 'Go on Facebook': -2.0141350136717633}, 'Class 2': {'Study': -0.64248088576, 'Fall asleep': 0.0}, 'Class 3': {'Study': 3.6, 'Go to the pub': 0.27988991999999996}, 'Facebook': {'Keep scrolling': -1.662522378698501, 'Close Facebook': -3.0165782955941673}, 'Pub': {'Have a pint': -1.1476224}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.6122448979591838, 'Go on Facebook': 0.3877551020408162}, 'Class 2': {'Study': 0.3877551020408162, 'Fall asleep': 0.6122448979591838}, 'Class 3': {'Study': 0.6122448979591838, 'Go to the pub': 0.3877551020408162}, 'Facebook': {'Keep scrolling': 0.6122448979591838, 'Close Facebook': 0.3877551020408162}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.7755102040816324
# =========================== EPISODE  13 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 2     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 3     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 4     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 5     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 6     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 7     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 8     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.8900488372224, 'Go on Facebook': -2.2177185788849285}, 'Class 2': {'Study': -0.64248088576, 'Fall asleep': 0.0}, 'Class 3': {'Study': 3.6, 'Go to the pub': 0.27988991999999996}, 'Facebook': {'Keep scrolling': -2.1528327626519994, 'Close Facebook': -3.2540798882553394}, 'Pub': {'Have a pint': -1.1476224}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.6224489795918369, 'Go on Facebook': 0.37755102040816313}, 'Class 2': {'Study': 0.37755102040816313, 'Fall asleep': 0.6224489795918369}, 'Class 3': {'Study': 0.6224489795918369, 'Go to the pub': 0.37755102040816313}, 'Facebook': {'Keep scrolling': 0.6224489795918369, 'Close Facebook': 0.37755102040816313}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.7551020408163263
# =========================== EPISODE  14 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 2     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 3     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 4     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 5     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 6     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 7     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 8     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 9     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 10    | Class 1  | Study          | -2.0   | Class 2    | False |
# | 11    | Class 2  | Study          | -2.0   | Class 3    | False |
# | 12    | Class 3  | Study          | 10.0   | Pass       | False |
# | 13    | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.91203906977792, 'Go on Facebook': -2.5327923136534185}, 'Class 2': {'Study': -0.2659847086079999, 'Fall asleep': 0.0}, 'Class 3': {'Study': 4.880000000000001, 'Go to the pub': 0.27988991999999996}, 'Facebook': {'Keep scrolling': -3.0486466914296697, 'Close Facebook': -3.414986951743475}, 'Pub': {'Have a pint': -1.1476224}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.6326530612244899, 'Go on Facebook': 0.36734693877551006}, 'Class 2': {'Study': 0.36734693877551006, 'Fall asleep': 0.6326530612244899}, 'Class 3': {'Study': 0.6326530612244899, 'Go to the pub': 0.36734693877551006}, 'Facebook': {'Keep scrolling': 0.6326530612244899, 'Close Facebook': 0.36734693877551006}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.7346938775510201
# =========================== EPISODE  15 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.9296312558223359, 'Go on Facebook': -2.5327923136534185}, 'Class 2': {'Study': 0.2656122331136003, 'Fall asleep': 0.0}, 'Class 3': {'Study': 5.904000000000001, 'Go to the pub': 0.27988991999999996}, 'Facebook': {'Keep scrolling': -3.0486466914296697, 'Close Facebook': -3.414986951743475}, 'Pub': {'Have a pint': -1.1476224}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.642857142857143, 'Go on Facebook': 0.357142857142857}, 'Class 2': {'Study': 0.642857142857143, 'Fall asleep': 0.357142857142857}, 'Class 3': {'Study': 0.642857142857143, 'Go to the pub': 0.357142857142857}, 'Facebook': {'Keep scrolling': 0.642857142857143, 'Close Facebook': 0.357142857142857}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.714285714285714
# =========================== EPISODE  16 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.8958948026974207, 'Go on Facebook': -2.5327923136534185}, 'Class 2': {'Study': 0.2656122331136003, 'Fall asleep': 0.0}, 'Class 3': {'Study': 5.904000000000001, 'Go to the pub': 0.27988991999999996}, 'Facebook': {'Keep scrolling': -3.0486466914296697, 'Close Facebook': -3.414986951743475}, 'Pub': {'Have a pint': -1.1476224}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.6530612244897961, 'Go on Facebook': 0.3469387755102039}, 'Class 2': {'Study': 0.6530612244897961, 'Fall asleep': 0.3469387755102039}, 'Class 3': {'Study': 0.6530612244897961, 'Go to the pub': 0.3469387755102039}, 'Facebook': {'Keep scrolling': 0.6530612244897961, 'Close Facebook': 0.3469387755102039}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.6938775510204078
# =========================== EPISODE  17 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 2     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 3     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 4     | Class 3  | Study          | 10.0   | Pass       | False |
# | 5     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.8689056401974886, 'Go on Facebook': -2.774990255380075}, 'Class 2': {'Study': 0.8752097864908805, 'Fall asleep': 0.0}, 'Class 3': {'Study': 6.7232, 'Go to the pub': 0.27988991999999996}, 'Facebook': {'Keep scrolling': -3.0486466914296697, 'Close Facebook': -3.4732506258803157}, 'Pub': {'Have a pint': -1.1476224}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.6632653061224492, 'Go on Facebook': 0.33673469387755084}, 'Class 2': {'Study': 0.6632653061224492, 'Fall asleep': 0.33673469387755084}, 'Class 3': {'Study': 0.6632653061224492, 'Go to the pub': 0.33673469387755084}, 'Facebook': {'Keep scrolling': 0.6632653061224492, 'Close Facebook': 0.33673469387755084}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.6734693877551017
# =========================== EPISODE  18 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.7375867505896323, 'Go on Facebook': -2.774990255380075}, 'Class 2': {'Study': 0.8752097864908805, 'Fall asleep': 0.0}, 'Class 3': {'Study': 6.7232, 'Go to the pub': 0.27988991999999996}, 'Facebook': {'Keep scrolling': -3.0486466914296697, 'Close Facebook': -3.4732506258803157}, 'Pub': {'Have a pint': -1.1476224}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.6734693877551022, 'Go on Facebook': 0.32653061224489777}, 'Class 2': {'Study': 0.6734693877551022, 'Fall asleep': 0.32653061224489777}, 'Class 3': {'Study': 0.6734693877551022, 'Go to the pub': 0.32653061224489777}, 'Facebook': {'Keep scrolling': 0.6734693877551022, 'Close Facebook': 0.32653061224489777}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.6530612244897955
# =========================== EPISODE  19 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.6325316389033473, 'Go on Facebook': -2.774990255380075}, 'Class 2': {'Study': 1.5103438291927045, 'Fall asleep': 0.0}, 'Class 3': {'Study': 7.37856, 'Go to the pub': 0.27988991999999996}, 'Facebook': {'Keep scrolling': -3.0486466914296697, 'Close Facebook': -3.4732506258803157}, 'Pub': {'Have a pint': -1.1476224}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.6836734693877553, 'Go on Facebook': 0.3163265306122447}, 'Class 2': {'Study': 0.6836734693877553, 'Fall asleep': 0.3163265306122447}, 'Class 3': {'Study': 0.6836734693877553, 'Go to the pub': 0.3163265306122447}, 'Facebook': {'Keep scrolling': 0.6836734693877553, 'Close Facebook': 0.3163265306122447}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.6326530612244894
# =========================== EPISODE  20 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 2     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 3     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 4     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 5     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 6     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 7     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.434163421867991, 'Go on Facebook': -2.9687486087614006}, 'Class 2': {'Study': 1.5103438291927045, 'Fall asleep': 0.0}, 'Class 3': {'Study': 7.37856, 'Go to the pub': 0.27988991999999996}, 'Facebook': {'Keep scrolling': -3.588293039264072, 'Close Facebook': -3.472456195706855}, 'Pub': {'Have a pint': -1.1476224}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.6938775510204084, 'Go on Facebook': 0.3061224489795916}, 'Class 2': {'Study': 0.6938775510204084, 'Fall asleep': 0.3061224489795916}, 'Class 3': {'Study': 0.6938775510204084, 'Go to the pub': 0.3061224489795916}, 'Facebook': {'Keep scrolling': 0.3061224489795916, 'Close Facebook': 0.6938775510204084}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.6122448979591832
# =========================== EPISODE  21 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.275468848239706, 'Go on Facebook': -2.9687486087614006}, 'Class 2': {'Study': 2.1364158633541637, 'Fall asleep': 0.0}, 'Class 3': {'Study': 7.9028480000000005, 'Go to the pub': 0.27988991999999996}, 'Facebook': {'Keep scrolling': -3.588293039264072, 'Close Facebook': -3.472456195706855}, 'Pub': {'Have a pint': -1.1476224}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.7040816326530615, 'Go on Facebook': 0.29591836734693855}, 'Class 2': {'Study': 0.7040816326530615, 'Fall asleep': 0.29591836734693855}, 'Class 3': {'Study': 0.7040816326530615, 'Go to the pub': 0.29591836734693855}, 'Facebook': {'Keep scrolling': 0.29591836734693855, 'Close Facebook': 0.7040816326530615}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.5918367346938771
# =========================== EPISODE  22 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 2     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 3     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 4     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 5     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 6     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 7     | Class 3  | Go to the pub  |  1.0   | Pub        | False |
# | 8     | Pub      | Have a pint    | -2.0   | Class 2    | False |
# | 9     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 10    | Class 3  | Go to the pub  |  1.0   | Pub        | False |
# | 11    | Pub      | Have a pint    | -2.0   | Class 2    | False |
# | 12    | Class 2  | Study          | -2.0   | Class 3    | False |
# | 13    | Class 3  | Go to the pub  |  1.0   | Pub        | False |
# | 14    | Pub      | Have a pint    | -2.0   | Class 2    | False |
# | 15    | Class 2  | Study          | -2.0   | Class 3    | False |
# | 16    | Class 3  | Study          | 10.0   | Pass       | False |
# | 17    | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -1.0358202231880154, 'Go on Facebook': -3.373391684653837}, 'Class 2': {'Study': 3.893533250909866, 'Fall asleep': 0.0}, 'Class 3': {'Study': 8.3222784, 'Go to the pub': 0.29302748804993584}, 'Facebook': {'Keep scrolling': -3.6956765466384915, 'Close Facebook': -3.3556238720820524}, 'Pub': {'Have a pint': -0.14099012699584068}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.7142857142857145, 'Go on Facebook': 0.2857142857142855}, 'Class 2': {'Study': 0.7142857142857145, 'Fall asleep': 0.2857142857142855}, 'Class 3': {'Study': 0.7142857142857145, 'Go to the pub': 0.2857142857142855}, 'Facebook': {'Keep scrolling': 0.2857142857142855, 'Close Facebook': 0.7142857142857145}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.571428571428571
# =========================== EPISODE  23 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -0.5278201933866363, 'Go on Facebook': -3.373391684653837}, 'Class 2': {'Study': 4.212836712727893, 'Fall asleep': 0.0}, 'Class 3': {'Study': 8.65782272, 'Go to the pub': 0.29302748804993584}, 'Facebook': {'Keep scrolling': -3.6956765466384915, 'Close Facebook': -3.3556238720820524}, 'Pub': {'Have a pint': -0.14099012699584068}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.7244897959183676, 'Go on Facebook': 0.2755102040816324}, 'Class 2': {'Study': 0.7244897959183676, 'Fall asleep': 0.2755102040816324}, 'Class 3': {'Study': 0.7244897959183676, 'Go to the pub': 0.2755102040816324}, 'Facebook': {'Keep scrolling': 0.2755102040816324, 'Close Facebook': 0.7244897959183676}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.5510204081632648
# =========================== EPISODE  24 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': -0.06394554641828831, 'Go on Facebook': -3.373391684653837}, 'Class 2': {'Study': 4.5286774597823145, 'Fall asleep': 0.0}, 'Class 3': {'Study': 8.926258176000001, 'Go to the pub': 0.29302748804993584}, 'Facebook': {'Keep scrolling': -3.6956765466384915, 'Close Facebook': -3.3556238720820524}, 'Pub': {'Have a pint': -0.14099012699584068}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.7346938775510207, 'Go on Facebook': 0.26530612244897933}, 'Class 2': {'Study': 0.7346938775510207, 'Fall asleep': 0.26530612244897933}, 'Class 3': {'Study': 0.7346938775510207, 'Go to the pub': 0.26530612244897933}, 'Facebook': {'Keep scrolling': 0.26530612244897933, 'Close Facebook': 0.7346938775510207}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.5306122448979587
# =========================== EPISODE  25 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 2     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 3     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 4     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 5     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 6     | Class 3  | Go to the pub  |  1.0   | Pub        | False |
# | 7     | Pub      | Have a pint    | -2.0   | Class 3    | False |
# | 8     | Class 3  | Study          | 10.0   | Pass       | False |
# | 9     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 0.36400550562618594, 'Go on Facebook': -3.5594621890420393}, 'Class 2': {'Study': 4.829668439505852, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.141006540800001, 'Go to the pub': 0.4090437675806973}, 'Facebook': {'Keep scrolling': -3.6956765466384915, 'Close Facebook': -2.888317635172039}, 'Pub': {'Have a pint': 1.093934370083328}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.7448979591836737, 'Go on Facebook': 0.25510204081632626}, 'Class 2': {'Study': 0.7448979591836737, 'Fall asleep': 0.25510204081632626}, 'Class 3': {'Study': 0.7448979591836737, 'Go to the pub': 0.25510204081632626}, 'Facebook': {'Keep scrolling': 0.25510204081632626, 'Close Facebook': 0.7448979591836737}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.5102040816326525
# =========================== EPISODE  26 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 2     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 3     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 4     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 5     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 6     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 7     | Class 3  | Study          | 10.0   | Pass       | False |
# | 8     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 0.7605447236120022, 'Go on Facebook': -3.5674669255645983}, 'Class 2': {'Study': 5.109115928948682, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.31280523264, 'Go to the pub': 0.4090437675806973}, 'Facebook': {'Keep scrolling': -3.6487354972464674, 'Close Facebook': -2.6451331171249177}, 'Pub': {'Have a pint': 1.093934370083328}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.7551020408163268, 'Go on Facebook': 0.2448979591836732}, 'Class 2': {'Study': 0.7551020408163268, 'Fall asleep': 0.2448979591836732}, 'Class 3': {'Study': 0.7551020408163268, 'Go to the pub': 0.2448979591836732}, 'Facebook': {'Keep scrolling': 0.2448979591836732, 'Close Facebook': 0.7551020408163268}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.4897959183673464
# =========================== EPISODE  27 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 2     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 3     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 4     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 5     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 6     | Class 3  | Study          | 10.0   | Pass       | False |
# | 7     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 1.1280766461003644, 'Go on Facebook': -3.4523355210482904}, 'Class 2': {'Study': 5.363597685034145, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.450244186112, 'Go to the pub': 0.4090437675806973}, 'Facebook': {'Keep scrolling': -3.6487354972464674, 'Close Facebook': -2.1664687045096587}, 'Pub': {'Have a pint': 1.093934370083328}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.7653061224489799, 'Go on Facebook': 0.2346938775510201}, 'Class 2': {'Study': 0.7653061224489799, 'Fall asleep': 0.2346938775510201}, 'Class 3': {'Study': 0.7653061224489799, 'Go to the pub': 0.2346938775510201}, 'Facebook': {'Keep scrolling': 0.2346938775510201, 'Close Facebook': 0.7653061224489799}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.4693877551020402
# =========================== EPISODE  28 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 1.4679089001864376, 'Go on Facebook': -3.4523355210482904}, 'Class 2': {'Study': 5.5919221015274765, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.5601953488896, 'Go to the pub': 0.4090437675806973}, 'Facebook': {'Keep scrolling': -3.6487354972464674, 'Close Facebook': -2.1664687045096587}, 'Pub': {'Have a pint': 1.093934370083328}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.775510204081633, 'Go on Facebook': 0.22448979591836704}, 'Class 2': {'Study': 0.775510204081633, 'Fall asleep': 0.22448979591836704}, 'Class 3': {'Study': 0.775510204081633, 'Go to the pub': 0.22448979591836704}, 'Facebook': {'Keep scrolling': 0.22448979591836704, 'Close Facebook': 0.775510204081633}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.4489795918367341
# =========================== EPISODE  29 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 1.780873098424096, 'Go on Facebook': -3.4523355210482904}, 'Class 2': {'Study': 5.794372844022109, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.64815627911168, 'Go to the pub': 0.4090437675806973}, 'Facebook': {'Keep scrolling': -3.6487354972464674, 'Close Facebook': -2.1664687045096587}, 'Pub': {'Have a pint': 1.093934370083328}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.785714285714286, 'Go on Facebook': 0.21428571428571397}, 'Class 2': {'Study': 0.785714285714286, 'Fall asleep': 0.21428571428571397}, 'Class 3': {'Study': 0.785714285714286, 'Go to the pub': 0.21428571428571397}, 'Facebook': {'Keep scrolling': 0.21428571428571397, 'Close Facebook': 0.785714285714286}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.42857142857142794
# =========================== EPISODE  30 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 2.0676855906632565, 'Go on Facebook': -3.4523355210482904}, 'Class 2': {'Study': 5.97216640545779, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.718525023289343, 'Go to the pub': 0.4090437675806973}, 'Facebook': {'Keep scrolling': -3.6487354972464674, 'Close Facebook': -2.1664687045096587}, 'Pub': {'Have a pint': 1.093934370083328}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.7959183673469391, 'Go on Facebook': 0.2040816326530609}, 'Class 2': {'Study': 0.7959183673469391, 'Fall asleep': 0.2040816326530609}, 'Class 3': {'Study': 0.7959183673469391, 'Go to the pub': 0.2040816326530609}, 'Facebook': {'Keep scrolling': 0.2040816326530609, 'Close Facebook': 0.7959183673469391}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.4081632653061218
# =========================== EPISODE  31 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 2.3291384255130074, 'Go on Facebook': -3.4523355210482904}, 'Class 2': {'Study': 6.127067628558313, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.774820018631475, 'Go to the pub': 0.4090437675806973}, 'Facebook': {'Keep scrolling': -3.6487354972464674, 'Close Facebook': -2.1664687045096587}, 'Pub': {'Have a pint': 1.093934370083328}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.8061224489795922, 'Go on Facebook': 0.19387755102040782}, 'Class 2': {'Study': 0.8061224489795922, 'Fall asleep': 0.19387755102040782}, 'Class 3': {'Study': 0.8061224489795922, 'Go to the pub': 0.19387755102040782}, 'Facebook': {'Keep scrolling': 0.19387755102040782, 'Close Facebook': 0.8061224489795922}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.38775510204081565
# =========================== EPISODE  32 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 2.5661829135509024, 'Go on Facebook': -3.4523355210482904}, 'Class 2': {'Study': 6.127067628558313, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.774820018631475, 'Go to the pub': 0.4090437675806973}, 'Facebook': {'Keep scrolling': -3.6487354972464674, 'Close Facebook': -2.1664687045096587}, 'Pub': {'Have a pint': 1.093934370083328}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.8163265306122452, 'Go on Facebook': 0.18367346938775475}, 'Class 2': {'Study': 0.8163265306122452, 'Fall asleep': 0.18367346938775475}, 'Class 3': {'Study': 0.8163265306122452, 'Go to the pub': 0.18367346938775475}, 'Facebook': {'Keep scrolling': 0.18367346938775475, 'Close Facebook': 0.8163265306122452}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.3673469387755095
# =========================== EPISODE  33 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# ...
# Epsilon: 0.22448979591836654
# =========================== EPISODE  40 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Keep scrolling | -1.0   | Facebook   | False |
# | 2     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 3     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 4     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 5     | Class 3  | Study          | 10.0   | Pass       | False |
# | 6     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 3.7474371352533367, 'Go on Facebook': -3.3518327836503707}, 'Class 2': {'Study': 6.774918848569527, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.952776335171304, 'Go to the pub': 0.724143200679557}, 'Facebook': {'Keep scrolling': -3.5089527646089125, 'Close Facebook': -1.4726447819417476}, 'Pub': {'Have a pint': 1.0319037372536501}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.8979591836734697, 'Go on Facebook': 0.10204081632653021}, 'Class 2': {'Study': 0.8979591836734697, 'Fall asleep': 0.10204081632653021}, 'Class 3': {'Study': 0.8979591836734697, 'Go to the pub': 0.10204081632653021}, 'Facebook': {'Keep scrolling': 0.10204081632653021, 'Close Facebook': 0.8979591836734697}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.20408163265306042
# =========================== EPISODE  41 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Go to the pub  |  1.0   | Pub        | False |
# | 3     | Pub      | Have a pint    | -2.0   | Class 1    | False |
# | 4     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 5     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 6     | Class 3  | Study          | 10.0   | Pass       | False |
# | 7     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 3.88000634820971, 'Go on Facebook': -3.3518327836503707}, 'Class 2': {'Study': 6.84064759568, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.962221068137044, 'Go to the pub': 0.9650572332493026}, 'Facebook': {'Keep scrolling': -3.5089527646089125, 'Close Facebook': -1.4726447819417476}, 'Pub': {'Have a pint': 1.1126613079730534}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.9081632653061229, 'Go on Facebook': 0.09183673469387715}, 'Class 2': {'Study': 0.9081632653061229, 'Fall asleep': 0.09183673469387715}, 'Class 3': {'Study': 0.9081632653061229, 'Go to the pub': 0.09183673469387715}, 'Facebook': {'Keep scrolling': 0.09183673469387715, 'Close Facebook': 0.9081632653061229}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.1836734693877543
# =========================== EPISODE  42 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Go to the pub  |  1.0   | Pub        | False |
# | 3     | Pub      | Have a pint    | -2.0   | Class 3    | False |
# | 4     | Class 3  | Study          | 10.0   | Pass       | False |
# | 5     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 3.935321645790168, 'Go on Facebook': -3.3518327836503707}, 'Class 2': {'Study': 6.865717868808668, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.969776854509636, 'Go to the pub': 1.1723248220345917}, 'Facebook': {'Keep scrolling': -3.5089527646089125, 'Close Facebook': -1.4726447819417476}, 'Pub': {'Have a pint': 2.2833288386431105}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.918367346938776, 'Go on Facebook': 0.0816326530612241}, 'Class 2': {'Study': 0.918367346938776, 'Fall asleep': 0.0816326530612241}, 'Class 3': {'Study': 0.918367346938776, 'Go to the pub': 0.0816326530612241}, 'Facebook': {'Keep scrolling': 0.0816326530612241, 'Close Facebook': 0.918367346938776}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.1632653061224482
# =========================== EPISODE  43 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Go on Facebook | -1.0   | Facebook   | False |
# | 1     | Facebook | Close Facebook | -2.0   | Class 1    | False |
# | 2     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 3     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 4     | Class 3  | Study          | 10.0   | Pass       | False |
# | 5     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 3.9840865330176944, 'Go on Facebook': -3.1465422876698113}, 'Class 2': {'Study': 6.887134128858669, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.975821483607708, 'Go to the pub': 1.1723248220345917}, 'Facebook': {'Keep scrolling': -3.5089527646089125, 'Close Facebook': -0.8697579293111678}, 'Pub': {'Have a pint': 2.2833288386431105}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.9285714285714289, 'Go on Facebook': 0.07142857142857104}, 'Class 2': {'Study': 0.9285714285714289, 'Fall asleep': 0.07142857142857104}, 'Class 3': {'Study': 0.9285714285714289, 'Go to the pub': 0.07142857142857104}, 'Facebook': {'Keep scrolling': 0.07142857142857104, 'Close Facebook': 0.9285714285714289}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.14285714285714207
# =========================== EPISODE  44 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.026953369608716, 'Go on Facebook': -3.1465422876698113}, 'Class 2': {'Study': 6.905355170136323, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.980657186886166, 'Go to the pub': 1.1723248220345917}, 'Facebook': {'Keep scrolling': -3.5089527646089125, 'Close Facebook': -0.8697579293111678}, 'Pub': {'Have a pint': 2.2833288386431105}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.938775510204082, 'Go on Facebook': 0.06122448979591798}, 'Class 2': {'Study': 0.938775510204082, 'Fall asleep': 0.06122448979591798}, 'Class 3': {'Study': 0.938775510204082, 'Go to the pub': 0.06122448979591798}, 'Facebook': {'Keep scrolling': 0.06122448979591798, 'Close Facebook': 0.938775510204082}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.12244897959183595
# =========================== EPISODE  45 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.064526626311511, 'Go on Facebook': -3.1465422876698113}, 'Class 2': {'Study': 6.920802429748568, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.984525749508933, 'Go to the pub': 1.1723248220345917}, 'Facebook': {'Keep scrolling': -3.5089527646089125, 'Close Facebook': -0.8697579293111678}, 'Pub': {'Have a pint': 2.2833288386431105}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.9489795918367351, 'Go on Facebook': 0.05102040816326492}, 'Class 2': {'Study': 0.9489795918367351, 'Fall asleep': 0.05102040816326492}, 'Class 3': {'Study': 0.9489795918367351, 'Go to the pub': 0.05102040816326492}, 'Facebook': {'Keep scrolling': 0.05102040816326492, 'Close Facebook': 0.9489795918367351}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.10204081632652984
# =========================== EPISODE  46 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.097365738403951, 'Go on Facebook': -3.1465422876698113}, 'Class 2': {'Study': 6.933856578710463, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.987620599607146, 'Go to the pub': 1.1723248220345917}, 'Facebook': {'Keep scrolling': -3.5089527646089125, 'Close Facebook': -0.8697579293111678}, 'Pub': {'Have a pint': 2.2833288386431105}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.9591836734693882, 'Go on Facebook': 0.04081632653061186}, 'Class 2': {'Study': 0.9591836734693882, 'Fall asleep': 0.04081632653061186}, 'Class 3': {'Study': 0.9591836734693882, 'Go to the pub': 0.04081632653061186}, 'Facebook': {'Keep scrolling': 0.04081632653061186, 'Close Facebook': 0.9591836734693882}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.08163265306122372
# =========================== EPISODE  47 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.125986774891045, 'Go on Facebook': -3.1465422876698113}, 'Class 2': {'Study': 6.944856970897657, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.990096479685716, 'Go to the pub': 1.1723248220345917}, 'Facebook': {'Keep scrolling': -3.5089527646089125, 'Close Facebook': -0.8697579293111678}, 'Pub': {'Have a pint': 2.2833288386431105}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.9693877551020412, 'Go on Facebook': 0.0306122448979588}, 'Class 2': {'Study': 0.9693877551020412, 'Fall asleep': 0.0306122448979588}, 'Class 3': {'Study': 0.9693877551020412, 'Go to the pub': 0.0306122448979588}, 'Facebook': {'Keep scrolling': 0.0306122448979588, 'Close Facebook': 0.9693877551020412}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.0612244897959176
# =========================== EPISODE  48 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.150863674674414, 'Go on Facebook': -3.1465422876698113}, 'Class 2': {'Study': 6.954102943061555, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.992077183748574, 'Go to the pub': 1.1723248220345917}, 'Facebook': {'Keep scrolling': -3.5089527646089125, 'Close Facebook': -0.8697579293111678}, 'Pub': {'Have a pint': 2.2833288386431105}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.9795918367346942, 'Go on Facebook': 0.020408163265305743}, 'Class 2': {'Study': 0.9795918367346942, 'Fall asleep': 0.020408163265305743}, 'Class 3': {'Study': 0.9795918367346942, 'Go to the pub': 0.020408163265305743}, 'Facebook': {'Keep scrolling': 0.020408163265305743, 'Close Facebook': 0.9795918367346942}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.040816326530611485
# =========================== EPISODE  49 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.172429469490611, 'Go on Facebook': -3.1465422876698113}, 'Class 2': {'Study': 6.961856247523987, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.993661746998859, 'Go to the pub': 1.1723248220345917}, 'Facebook': {'Keep scrolling': -3.5089527646089125, 'Close Facebook': -0.8697579293111678}, 'Pub': {'Have a pint': 2.2833288386431105}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 0.9897959183673473, 'Go on Facebook': 0.010204081632652682}, 'Class 2': {'Study': 0.9897959183673473, 'Fall asleep': 0.010204081632652682}, 'Class 3': {'Study': 0.9897959183673473, 'Go to the pub': 0.010204081632652682}, 'Facebook': {'Keep scrolling': 0.010204081632652682, 'Close Facebook': 0.9897959183673473}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0.020408163265305364
# =========================== EPISODE  50 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.191077700146806, 'Go on Facebook': -3.1465422876698113}, 'Class 2': {'Study': 6.968344112478984, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.994929397599087, 'Go to the pub': 1.1723248220345917}, 'Facebook': {'Keep scrolling': -3.5089527646089125, 'Close Facebook': -0.8697579293111678}, 'Pub': {'Have a pint': 2.2833288386431105}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0

# %% [markdown]
# Try with $\gamma=0$ and different $\epsilon$ values
