# %% [markdown]
# # 3 | Policy Improvement: The Q-learning Algorithm
#
# Having evaluated our policy $\pi$, how can we go about obtaining a better one? This question is the heart of *policy improvement*, perhaps the fundamental concept of RL. Recall, when we performed policy evaluation we obtained the value of taking every action in every state. Thus, we can perform policy improvement readily by picking our current best estimate of the optimal action from each state -- so-called *greedy* action selection. Once we've obtained a new policy, we can evaluate it as before. Continually iterating between policy evaluation and policy improvement in this way, we are guarenteed to reach the optimal policy $\pi^*$ according to the policy improvement theorem.

# %%
from mdp import StudentMDP
mdp = StudentMDP(verbose=True)

# %%
from agent import QLearningAgent
agent = QLearningAgent(mdp, epsilon=1.0, alpha=0.2, gamma=0.9)

# %%
NUM_EPS = 50
mdp.ep = 0
while mdp.ep < NUM_EPS:
    state = mdp.reset()
    done = False
    while not done:
        action = agent.act(state)
        next_state, reward, done, info = mdp.step(action)
        agent.learn(state, action, reward, next_state, done)
        state = next_state

    agent.epsilon = max(agent.epsilon - 1 / NUM_EPS, 0)

    print("Value function:")
    print(agent.Q)
    print("Policy:")
    print(agent.policy)
    print("Epsilon:", agent.epsilon)
# Out:
# =========================== EPISODE   1 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.269535585254451, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.9910254009365325, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.998670772004214, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE   2 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.274013040372137, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.992581059709985, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.998936617603372, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE   3 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.277875023045507, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.993873438936594, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999149294082697, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE   4 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.281197237444992, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.994945624084161, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999319435266157, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE   5 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.284048002291143, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.995833997615237, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999455548212925, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE   6 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.2864885214036565, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.996569196770516, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.99956443857034, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE   7 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.288573272541618, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.997176956359074, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999651550856273, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE   8 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.290350470177928, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.997678844241388, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999721240685018, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE   9 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.291862568105792, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.998092898716414, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999776992548014, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  10 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.293146776253588, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.998434177631774, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999821594038412, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  11 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.294235572976589, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.998715229032333, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.99985727523073, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  12 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.295157199607091, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.998946492767398, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999885820184584, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  13 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.295936128383805, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.9991366418471435, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999908656147667, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  14 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.29659349823953, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.999292871584295, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999926924918134, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  15 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.297147515476797, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.9994211437527, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999941539934508, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  16 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.297613818256924, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.999526392190372, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999953231947606, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  17 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.298005805199806, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.999612695502867, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999962585558084, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  18 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.298334929350361, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.999683421802748, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999970068446467, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  19 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.298610959404783, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.999741349762563, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999976054757173, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  20 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.298842210481088, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.999788769666342, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999980843805739, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  21 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.299035746924812, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.999827567618107, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.99998467504459, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  22 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.299197559711109, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.999859295602512, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999987740035673, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  23 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.29933272097734, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.999885229688431, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999990192028537, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  24 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.29944551812579, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.999906418315882, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.99999215362283, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  25 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.29953956979749, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.999923722304815, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999993722898264, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  26 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.299617925852859, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.99993784796554, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999994978318611, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  27 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.299683153316084, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.999949374469782, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.99999598265489, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  28 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.299737410057428, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.999958776453706, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999996786123912, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  29 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.29978250780761, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.9999664426652695, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.99999742889913, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  30 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.2998199659258365, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.999972691334059, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999997943119304, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  31 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.2998510571808, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.999977782828722, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999998354495442, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  32 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.29987684665381, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.999981930072158, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999998683596354, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  33 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.299898224736037, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.99998530710507, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999998946877083, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  34 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.299915935067742, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.999988056121931, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999999157501666, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  35 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.299930598156141, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.999990293247845, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999999326001333, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  36 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.2999427313095255, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.999992113278516, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999999460801067, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  37 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.299952765437753, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.999993593567005, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999999568640854, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  38 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.299961059192264, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.999994797208958, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999999654912683, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  39 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.299967910851423, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.999995775651449, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999999723930147, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  40 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.299973568298399, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.999996570828586, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999999779144117, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  41 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.299978237387864, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.99999721690881, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999999823315294, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  42 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.299982088953877, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.999997741723801, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999999858652235, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  43 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.299985264673386, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.999998167936443, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999999886921788, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  44 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.299987881967269, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.999998513995076, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999999909537431, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  45 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.299990038092929, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.999998794912798, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999999927629945, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  46 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.299991813558647, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.999999022903629, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999999942103956, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  47 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.29999327496957, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.999999207901616, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999999953683165, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  48 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.299994477397947, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.9999993579842625, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999999962946532, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  49 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.299995466355525, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.999999479717786, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999999970357226, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0
# =========================== EPISODE  50 ===========================
# | Time  | State    | Action         | Reward | Next state | Done  |
# |-------|----------|----------------|--------|------------|-------|
# | 0     | Class 1  | Study          | -2.0   | Class 2    | False |
# | 1     | Class 2  | Study          | -2.0   | Class 3    | False |
# | 2     | Class 3  | Study          | 10.0   | Pass       | False |
# | 3     | Pass     | Fall asleep    |  0.0   | Asleep     | True  |
# Value function:
# {'Class 1': {'Study': 4.299996279433621, 'Go on Facebook': -2.1411110193198555}, 'Class 2': {'Study': 6.99999957843853, 'Fall asleep': 0.0}, 'Class 3': {'Study': 9.999999976285782, 'Go to the pub': 3.524094056371283}, 'Facebook': {'Keep scrolling': -3.540110785757775, 'Close Facebook': 0.4320070069904297}, 'Pub': {'Have a pint': 4.898789244100201}, 'Pass': {'Fall asleep': 0.0}, 'Asleep': {'Stay asleep': 0.0}}
# Policy:
# {'Class 1': {'Study': 1.0, 'Go on Facebook': 0.0}, 'Class 2': {'Study': 1.0, 'Fall asleep': 0.0}, 'Class 3': {'Study': 1.0, 'Go to the pub': 0.0}, 'Facebook': {'Keep scrolling': 0.0, 'Close Facebook': 1.0}, 'Pub': {'Have a pint': 1.0}, 'Pass': {'Fall asleep': 1.0}, 'Asleep': {'Stay asleep': 1.0}}
# Epsilon: 0

# %% [markdown]
# Try with $\gamma=0$ and different $\epsilon$ values
